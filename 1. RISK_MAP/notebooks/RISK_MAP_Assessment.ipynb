# %% [markdown]
# # RISK-MAP Security Assessment
#
# This notebook runs the RISK-MAP scoring pipeline for all robots. It computes:
# - Overall and per-layer security scores
# - Individual radar charts and heatmaps
# - Combined radar + heatmap across platforms

# %%
# Step 1: Setup & Imports
import os

# Step 1: Setup & Imports – Anonymized version
project_root = os.path.abspath("..")
scripts_path = os.path.join(project_root, "scripts")

if os.path.isdir(scripts_path):
    os.chdir(scripts_path)
    print("[✓] Changed working directory to: scripts/")
else:
    raise FileNotFoundError("Required 'scripts/' folder not found in the project structure.")
# Out:
# [✓] Changed working directory to: scripts/

# %%
# Step 2: Run the main RISK-MAP scoring script
# !python score_RISK_MAP.py
# Out:
# [✓]    Digit: RISK_MAP  79.5%  → figures\Digit
# [✓]   G1_EDU: RISK_MAP  48.9%  → figures\G1_EDU
# [✓]   Pepper: RISK_MAP  39.9%  → figures\Pepper
# [✓] Saved per-layer scores CSV
# [✓] Combined radar saved

# %%
# Step 3: Display generated outputs
from IPython.display import Image, display

for robot in ["Digit", "G1_EDU", "Pepper"]:
    print(f"### {robot}")
    display(Image(filename=f"../figures/{robot}/radar.png"))
    display(Image(filename=f"../figures/{robot}/heatmap.png"))
# Out:
# ### Digit
# ### G1_EDU
# ### Pepper

# %%
# Step 4: Show combined charts
from IPython.display import Image, display

# Combined charts
display(Image(filename="../figures/RISK_MAP_combined_radar.png"))
display(Image(filename="../figures/combined_heatmap_safe_r.png"))
